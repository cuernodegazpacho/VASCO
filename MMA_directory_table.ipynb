# %% [raw]
# # Convert MMA directory CSV file into an astropy Table

# %%
# %pylab notebook
# %matplotlib notebook

import os, glob
import csv

import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

from astropy.table import Table
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
with open('MMA_directory.txt', 'r') as csvfile:
    dict_reader = csv.DictReader(csvfile)
    for row in dict_reader:
        print(row['ColumnName1'], row['ColumnName2']) # Access by column name

# %%
# Extracts exposure EXIF data from a list of images

def get_metadata(dirpath, verbose=True):
    
    total_exptime = 0.
    
    list_files = glob.glob(dirpath + '/*' + ARW_suffix)
    
    table = Table(names=('ISO', 'Exptime', 'f/stop', 'Exposure', 'Date', 'File'), 
                  dtype=('f4','f4','f4','f4','S2', 'S2'))
    
    for filename in list_files:
        f = open(filename, 'rb')
        tags = exifread.process_file(f)
        iso = ''
        exptime = ''

        for tag in tags.keys():
            if tag in ['EXIF ExposureTime']:
                exptime = tags[tag]
            if tag in ['EXIF ISOSpeedRatings']:
                iso = tags[tag]
            if tag in ['Image DateTime']:
                date = tags[tag]
                
        index = filename.split('_')[-1].rfind('.')
        iso = float(str(iso))
        date = str(date)
        try:
            fstop = float(filename.split('_')[-1][:index][1:])
        except ValueError:
            fstop = 2.8
            
        exptime_str = str(exptime)
        if '/' in exptime_str:
            exptime_tokens = exptime_str.split('/')
            exptime = float(exptime_tokens[0]) / float(exptime_tokens[1])
        else:
            exptime = float(exptime_str)
            
        total_exptime += exptime
        
        exposure = (exptime/3.2) * (iso/100) / (fstop/2.8)**2
        
        filename_stripped = filename.split('astrophotography_data')[1]
        
        table.add_row((iso, exptime, fstop, exposure, date, filename_stripped))

    table.sort('Date')  
    
    if verbose:
        print("Total exptime =", total_exptime, "sec.  -  Total files =", len(list_files))
    
    return table, total_exptime

# %%
dirpath = os.path.join(DATA,'Andromeda_2022/105MSDCF')
t, _ = get_metadata(dirpath)
t.pprint_all()
# Out:
# Total exptime = 298.0 sec.  -  Total files = 149
#  ISO   Exptime f/stop Exposure         Date                         File
# ------ ------- ------ -------- ------------------- -------------------------------------
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:12 /Andromeda_2022/105MSDCF/DSC00001.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:15 /Andromeda_2022/105MSDCF/DSC00002.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:19 /Andromeda_2022/105MSDCF/DSC00003.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:23 /Andromeda_2022/105MSDCF/DSC00004.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:26 /Andromeda_2022/105MSDCF/DSC00005.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:30 /Andromeda_2022/105MSDCF/DSC00006.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:34 /Andromeda_2022/105MSDCF/DSC00007.ARW
# 1600.0     2.0    2.8     10.0 2022:10:29 23:57:37 /Andromeda_2022/105MSDCF/DSC00008.ARW
# ...

# %%
# compute total exptime in all directories in list
total_time_list = [
    'Andromeda_2023/104MSDCF',
    'Andromeda_2023/105MSDCF',
    'Andromeda_2023/106MSDCF',
    'Andromeda_2023/107MSDCF',
    'Andromeda_2023/108MSDCF',
    'Andromeda_2023/109MSDCF',
    'Andromeda_2023/Nov12/100MSDCF',
    'Andromeda_2023/Nov12/101MSDCF',
    'Andromeda_2023/Nov12/102MSDCF',
    'Andromeda_2023/Nov12/103MSDCF',
    'Andromeda_2023/Nov12/104MSDCF',
    'Andromeda_2024/100MSDCF',
    'Andromeda_2024/103MSDCF',
]

total_time_list = combined_paths

tt = 0.

for name in total_time_list:
    dirpath = os.path.join(DATA, name)
    _, t_dir = get_metadata(dirpath, verbose=False)
    tt += t_dir
    
    print(name, t_dir)
    
print (tt)
# Out:
# Andromeda_2024/100MSDCF 872.2999999999905
# Andromeda_2022/104p105 2.0
# Andromeda_2022/85mm2s1600ISO_3 420.0
# Andromeda_2024/103MSDCF 1046.4999999999845
# Andromeda_2023/Nov12/100MSDCF 1014.4000000000101
# Andromeda_2023/Nov12/101MSDCF 521.6000000000031
# Andromeda_2023/Nov12/102MSDCF 1014.4000000000101
# Andromeda_2023/Nov12/103MSDCF 521.6000000000031
# Andromeda_2023/Nov12/104MSDCF 937.600000000009
# Andromeda_2023/104MSDCF 1420.7999999999877
# Andromeda_2023/105MSDCF 1439.9999999999866
# Andromeda_2023/106MSDCF 425.6000000000017
# Andromeda_2023/107MSDCF 246.39999999999938
# Andromeda_2023/108MSDCF 1371.1999999999905
# Andromeda_2023/109MSDCF 1535.9999999999811
# Andromeda_2024/Elk_Neck/100MSDCF 2189.1999999999694
# 14979.599999999928
